# %%
import pandas as pd

# %%
df1 = pd.read_csv("202407-Cyclistic.csv")

# %%
df1.head(20)
# Out:
#              ride_id  rideable_type     started_at       ended_at  \
# 0   5ABC2B54997B28B8  electric_bike  7/20/24 22:36  7/20/24 22:37
# 1   AF80EED448C3804C  electric_bike   7/4/24 19:11   7/4/24 19:11
# 2   EC08BDF3385C7398  electric_bike  7/20/24 12:03  7/20/24 12:04
# 3   335DF178CAB7F5B7  electric_bike   7/24/24 9:35   7/24/24 9:35
# 4   9180BBD9B9ADF995  electric_bike   7/6/24 17:28   7/6/24 17:29
# 5   A8E4F8285F85BE7A  electric_bike   7/6/24 14:41   7/6/24 14:42
# 6   567537575913EAA0  electric_bike   7/5/24 19:18   7/5/24 19:19
# 7   D826F6DC85F8F71E  electric_bike   7/3/24 17:24   7/3/24 17:24
# 8   0FA96001D692176A  electric_bike  7/27/24 14:52  7/27/24 14:53
# 9   8376B42608763499  electric_bike  7/27/24 16:49  7/27/24 16:50
# 10  BE596CF869AF81C6  electric_bike  7/25/24 18:48  7/25/24 18:49
# 11  1D7125D2409F9582  electric_bike   7/1/24 15:44   7/1/24 15:45
# 12  A5AC493C1D33D2D2  electric_bike  7/31/24 21:23  7/31/24 21:24
# 13  7F49D7BA52C2855C  electric_bike  7/13/24 10:32  7/13/24 10:32
# 14  70665065C7220463  electric_bike  7/26/24 16:43  7/26/24 16:43
# 15  767F87FDC72BE5D8  electric_bike  7/19/24 18:57  7/19/24 18:58
# 16  71AA2162020E0D74  electric_bike  7/30/24 22:05  7/30/24 22:06
# 17  120011B26D7D40A4  electric_bike  7/31/24 18:57  7/31/24 18:57
# 18  8CDC591E09A8F098  electric_bike    7/4/24 9:24    7/4/24 9:24
# 19  9F19935ED90B4702  electric_bike  7/14/24 11:57  7/14/24 11:58
#
#     day_of_week  ride_length start_station_name start_station_id  \
# 0             7           31                NaN              NaN
# 1             5           31                NaN              NaN
# 2             7           31                NaN              NaN
# 3             4           31                NaN              NaN
# 4             7           31                NaN              NaN
# 5             7           31                NaN              NaN
# 6             6           31                NaN              NaN
# 7             4           31                NaN              NaN
# 8             7           31                NaN              NaN
# 9             7           31                NaN              NaN
# 10            5           31                NaN              NaN
# 11            2           31                NaN              NaN
# 12            4           31                NaN              NaN
# 13            7           31                NaN              NaN
# 14            6           31                NaN              NaN
# 15            6           31                NaN              NaN
# 16            3           31                NaN              NaN
# 17            4           31                NaN              NaN
# 18            5           31                NaN              NaN
# 19            1           31                NaN              NaN
#
#    end_station_name end_station_id  start_lat  start_lng  end_lat  end_lng  \
# 0               NaN            NaN      41.85     -87.62    41.85   -87.62
# 1               NaN            NaN      41.86     -87.61    41.86   -87.61
# 2               NaN            NaN      41.92     -87.64    41.92   -87.64
# 3               NaN            NaN      41.89     -87.62    41.89   -87.62
# 4               NaN            NaN      41.74     -87.53    41.74   -87.53
# 5               NaN            NaN      41.92     -87.64    41.92   -87.64
# 6               NaN            NaN      41.98     -87.66    41.98   -87.66
# 7               NaN            NaN      41.93     -87.63    41.93   -87.63
# 8               NaN            NaN      41.88     -87.62    41.88   -87.62
# 9               NaN            NaN      41.93     -87.63    41.93   -87.63
# 10              NaN            NaN      41.78     -87.59    41.78   -87.59
# 11              NaN            NaN      41.93     -87.64    41.93   -87.64
# 12              NaN            NaN      41.89     -87.61    41.89   -87.61
# 13              NaN            NaN      41.90     -87.63    41.90   -87.63
# 14              NaN            NaN      41.91     -87.63    41.91   -87.63
# 15              NaN            NaN      41.89     -87.63    41.89   -87.63
# 16              NaN            NaN      41.91     -87.66    41.91   -87.66
# 17              NaN            NaN      41.87     -87.65    41.87   -87.65
# 18              NaN            NaN      41.95     -87.65    41.95   -87.65
# 19              NaN            NaN      41.94     -87.67    41.94   -87.67
#
#    member_casual  Unnamed: 15
# 0         casual          NaN
# 1         casual          NaN
# 2         casual          NaN
# 3         casual          NaN
# 4         casual          NaN
# 5         casual          NaN
# 6         casual          NaN
# 7         casual          NaN
# 8         casual          NaN
# 9         casual          NaN
# 10        casual          NaN
# 11        casual          NaN
# 12        casual          NaN
# 13        casual          NaN
# 14        casual          NaN
# 15        casual          NaN
# 16        casual          NaN
# 17        casual          NaN
# 18        casual          NaN
# 19        casual          NaN

# %%
import matplotlib.pyplot as plt

# %%
df1_weekday_count = df1[['day_of_week','member_casual']].value_counts()

# %%
df1_weekday_count.head(14)
# Out:
# day_of_week  member_casual
# 4            member           77211
# 3            member           70572
# 7            casual           66035
# 2            member           65210
# 5            member           57147
# 6            member           57143
# 7            member           55029
# 6            casual           48068
# 4            casual           45163
# 1            member           41165
#              casual           40913
# 5            casual           39901
# 2            casual           36843
# 3            casual           36154
# Name: count, dtype: int64

# %%
weekday_count_df = df1_weekday_count.reset_index()
weekday_count_df.columns = ['day_of_week', 'member_casual' , 'count']
weekday_count_df.head(15)
# Out:
#     day_of_week member_casual  count
# 0             4        member  77211
# 1             3        member  70572
# 2             7        casual  66035
# 3             2        member  65210
# 4             5        member  57147
# 5             6        member  57143
# 6             7        member  55029
# 7             6        casual  48068
# 8             4        casual  45163
# 9             1        member  41165
# 10            1        casual  40913
# 11            5        casual  39901
# 12            2        casual  36843
# 13            3        casual  36154

# %%
pivot_df1 = weekday_count_df.pivot_table(index='day_of_week' , columns='member_casual' , values='count')
pivot_df1
# Out:
# member_casual   casual   member
# day_of_week
# 1              40913.0  41165.0
# 2              36843.0  65210.0
# 3              36154.0  70572.0
# 4              45163.0  77211.0
# 5              39901.0  57147.0
# 6              48068.0  57143.0
# 7              66035.0  55029.0

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_df1['weekday'] = weekday

# %%
pivot_df1.plot(kind='bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
df1.hist(column='ride_length', bins=[30,120,300,600,1800,3600,10800,36000], by='member_casual')
plt.show()

# %%
df1_weekday_bike_membership = df1[['day_of_week','member_casual' , 'rideable_type']].value_counts()

# %%
weekday_bike_membership = df1_weekday_bike_membership.reset_index()

# %%
weekday_bike_membership.columns = ['day_of_week' , 'member_casual' , 'rideable_type' , 'count']

# %%
pivot_wbm = weekday_bike_membership.pivot_table(index = 'day_of_week' , columns = ['member_casual' , 'rideable_type'] , values = 'count')

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_wbm['weekday'] = weekday

# %%
pivot_wbm.plot(kind = 'bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
member_geo_data = df1[df1['member_casual']=='member']
member_geo_data = member_geo_data[['start_lat' , 'start_lng']]

# %%
member_geo_data.head()
# Out:
#     start_lat  start_lng
# 23  41.880000 -87.630000
# 24  41.890000 -87.660000
# 38  41.950000 -87.660000
# 39  41.854122 -87.619120
# 43  41.880118 -87.635634

# %%
HeatMap(member_geo_data).add_to(m)

# %%
m.save('heatmapmember-July.html')

# %%
casual_geo_data = df1[df1['member_casual']=='casual']
casual_geo_route = casual_geo_data[['start_lat' , 'start_lng' , 'end_lat' , 'end_lng']]
casual_geo_data = casual_geo_data[['start_lat' , 'start_lng']]

# %%
m1 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
HeatMap(casual_geo_data).add_to(m1)

# %%
m1.save('heatmapcasual-July.html')

# %%
m2 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
casual_geo_route.head()
# Out:
#    start_lat  start_lng  end_lat  end_lng
# 0      41.85     -87.62    41.85   -87.62
# 1      41.86     -87.61    41.86   -87.61
# 2      41.92     -87.64    41.92   -87.64
# 3      41.89     -87.62    41.89   -87.62
# 4      41.74     -87.53    41.74   -87.53

# %%
casual_geo_route = casual_geo_route.dropna()
for index in casual_geo_route.index:
    route = [[casual_geo_route.loc[index, 'start_lat'] ,casual_geo_route.loc[index,'start_lng']] , [casual_geo_route.loc[index,'end_lat'], casual_geo_route.loc[index,'end_lng']]] 
    folium.PolyLine(locations = route , color='blue' , weight=0.5 , opacity = 0.4).add_to(m2)

# %%
m2.save('routesCasual-July.html')

# %% [markdown]
# ##
