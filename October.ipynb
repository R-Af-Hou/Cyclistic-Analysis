# %%
import pandas as pd

# %%
df1 = pd.read_csv("202410-Cyclistic.csv")

# %%
df1.head(20)
# Out:
#              ride_id  rideable_type      started_at        ended_at  \
# 0   065AADDE77290B24  electric_bike   10/13/24 6:42   10/13/24 6:43
# 1   8A09C88632998B78  electric_bike  10/11/24 12:19  10/11/24 12:20
# 2   C3B369013DC8D98B  electric_bike  10/13/24 20:04  10/13/24 20:05
# 3   0B1D65E39D29D47C  electric_bike  10/20/24 15:51  10/20/24 15:52
# 4   D7AC4BCD1ADBC09A  electric_bike   10/18/24 7:52   10/18/24 7:52
# 5   0763235FE93F4EAA  electric_bike   10/5/24 17:52   10/5/24 17:53
# 6   4A3EFBAF22134551  electric_bike   10/5/24 16:42   10/5/24 16:43
# 7   752AFA14F8459EC8  electric_bike   10/4/24 20:39   10/4/24 20:40
# 8   9C1322E102C5C28B  electric_bike   10/13/24 6:55   10/13/24 6:55
# 9   38B3BC2220EDD348  electric_bike  10/13/24 15:04  10/13/24 15:04
# 10  E4AA716F2F3CE923  electric_bike  10/17/24 16:20  10/17/24 16:21
# 11  1509D55D8C77F9B0  electric_bike   10/1/24 22:47   10/1/24 22:47
# 12  871C40034AE08377  electric_bike   10/2/24 17:40   10/2/24 17:40
# 13  B26D31DC61826338  electric_bike    10/2/24 9:36    10/2/24 9:36
# 14  A90A49D04463B92B  electric_bike  10/24/24 15:44  10/24/24 15:45
# 15  BBA977717B56D4BA  electric_bike   10/28/24 5:25   10/28/24 5:25
# 16  CB8B6242833838E3  electric_bike  10/18/24 13:39  10/18/24 13:39
# 17  976CE6FBF4D3C0BF  electric_bike   10/1/24 17:09   10/1/24 17:09
# 18  59898524AEC383F3  electric_bike  10/22/24 11:16  10/22/24 11:17
# 19  B0056FDA4EC70332  electric_bike   10/27/24 0:01   10/27/24 0:01
#
#     day_of_week  ride_length start_station_name start_station_id  \
# 0             1           31                NaN              NaN
# 1             6           31                NaN              NaN
# 2             1           31                NaN              NaN
# 3             1           31                NaN              NaN
# 4             6           31                NaN              NaN
# 5             7           31                NaN              NaN
# 6             7           31                NaN              NaN
# 7             6           31                NaN              NaN
# 8             1           31                NaN              NaN
# 9             1           31                NaN              NaN
# 10            5           31                NaN              NaN
# 11            3           31                NaN              NaN
# 12            4           31                NaN              NaN
# 13            4           31                NaN              NaN
# 14            5           31                NaN              NaN
# 15            2           31                NaN              NaN
# 16            6           31                NaN              NaN
# 17            3           31                NaN              NaN
# 18            3           31                NaN              NaN
# 19            1           31                NaN              NaN
#
#    end_station_name end_station_id  start_lat  start_lng  end_lat  end_lng  \
# 0               NaN            NaN      41.90     -87.68    41.90   -87.68
# 1               NaN            NaN      41.91     -87.63    41.91   -87.63
# 2               NaN            NaN      41.93     -87.64    41.93   -87.64
# 3               NaN            NaN      41.93     -87.64    41.93   -87.64
# 4               NaN            NaN      41.94     -87.66    41.94   -87.66
# 5               NaN            NaN      41.89     -87.65    41.89   -87.65
# 6               NaN            NaN      41.93     -87.63    41.93   -87.63
# 7               NaN            NaN      41.89     -87.62    41.89   -87.62
# 8               NaN            NaN      41.89     -87.66    41.89   -87.66
# 9               NaN            NaN      41.88     -87.63    41.88   -87.63
# 10              NaN            NaN      41.74     -87.55    41.74   -87.55
# 11              NaN            NaN      41.89     -87.63    41.89   -87.63
# 12              NaN            NaN      41.74     -87.55    41.74   -87.55
# 13              NaN            NaN      41.74     -87.55    41.74   -87.55
# 14              NaN            NaN      41.89     -87.62    41.89   -87.62
# 15              NaN            NaN      41.92     -87.70    41.92   -87.70
# 16              NaN            NaN      41.89     -87.61    41.89   -87.61
# 17              NaN            NaN      41.98     -87.67    41.98   -87.67
# 18              NaN            NaN      41.94     -87.64    41.94   -87.64
# 19              NaN            NaN      41.90     -87.63    41.90   -87.63
#
#    member_casual  Unnamed: 15
# 0         member          NaN
# 1         casual          NaN
# 2         casual          NaN
# 3         casual          NaN
# 4         casual          NaN
# 5         casual          NaN
# 6         casual          NaN
# 7         casual          NaN
# 8         casual          NaN
# 9         casual          NaN
# 10        member          NaN
# 11        member          NaN
# 12        member          NaN
# 13        member          NaN
# 14        casual          NaN
# 15        casual          NaN
# 16        casual          NaN
# 17        member          NaN
# 18        member          NaN
# 19        member          NaN

# %%
import matplotlib.pyplot as plt

# %%
df1_weekday_count = df1[['day_of_week','member_casual']].value_counts()

# %%
df1_weekday_count.head(14)
# Out:
# day_of_week  member_casual
# 4            member           72423
# 5            member           68931
# 3            member           66094
# 6            member           52447
# 2            member           48524
# 7            member           46620
#              casual           41839
# 1            member           41206
#              casual           38437
# 6            casual           30909
# 5            casual           28799
# 4            casual           27085
# 3            casual           24223
# 2            casual           20836
# Name: count, dtype: int64

# %%
weekday_count_df = df1_weekday_count.reset_index()
weekday_count_df.columns = ['day_of_week', 'member_casual' , 'count']
weekday_count_df.head(15)
# Out:
#     day_of_week member_casual  count
# 0             4        member  72423
# 1             5        member  68931
# 2             3        member  66094
# 3             6        member  52447
# 4             2        member  48524
# 5             7        member  46620
# 6             7        casual  41839
# 7             1        member  41206
# 8             1        casual  38437
# 9             6        casual  30909
# 10            5        casual  28799
# 11            4        casual  27085
# 12            3        casual  24223
# 13            2        casual  20836

# %%
pivot_df1 = weekday_count_df.pivot_table(index='day_of_week' , columns='member_casual' , values='count')
pivot_df1
# Out:
# member_casual   casual   member
# day_of_week
# 1              38437.0  41206.0
# 2              20836.0  48524.0
# 3              24223.0  66094.0
# 4              27085.0  72423.0
# 5              28799.0  68931.0
# 6              30909.0  52447.0
# 7              41839.0  46620.0

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_df1['weekday'] = weekday

# %%
pivot_df1.plot(kind='bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
df1.hist(column='ride_length', bins=[30,120,300,600,1800,3600,10800,36000], by='member_casual')
plt.show()

# %%
df1_weekday_bike_membership = df1[['day_of_week','member_casual' , 'rideable_type']].value_counts()

# %%
weekday_bike_membership = df1_weekday_bike_membership.reset_index()

# %%
weekday_bike_membership.columns = ['day_of_week' , 'member_casual' , 'rideable_type' , 'count']

# %%
pivot_wbm = weekday_bike_membership.pivot_table(index = 'day_of_week' , columns = ['member_casual' , 'rideable_type'] , values = 'count')

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_wbm['weekday'] = weekday

# %%
pivot_wbm.plot(kind = 'bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
member_geo_data = df1[df1['member_casual']=='member']
member_geo_data = member_geo_data[['start_lat' , 'start_lng']]

# %%
member_geo_data.head()
# Out:
#     start_lat  start_lng
# 0       41.90     -87.68
# 10      41.74     -87.55
# 11      41.89     -87.63
# 12      41.74     -87.55
# 13      41.74     -87.55

# %%
HeatMap(member_geo_data).add_to(m)

# %%
m.save('heatmapmember-October.html')

# %%
casual_geo_data = df1[df1['member_casual']=='casual']
casual_geo_route = casual_geo_data[['start_lat' , 'start_lng' , 'end_lat' , 'end_lng']]
casual_geo_data = casual_geo_data[['start_lat' , 'start_lng']]

# %%
m1 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
HeatMap(casual_geo_data).add_to(m1)

# %%
m1.save('heatmapcasual-October.html')

# %%
m2 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
casual_geo_route.head()
# Out:
#    start_lat  start_lng  end_lat  end_lng
# 1      41.91     -87.63    41.91   -87.63
# 2      41.93     -87.64    41.93   -87.64
# 3      41.93     -87.64    41.93   -87.64
# 4      41.94     -87.66    41.94   -87.66
# 5      41.89     -87.65    41.89   -87.65

# %%
casual_geo_route = casual_geo_route.dropna()
for index in casual_geo_route.index:
    route = [[casual_geo_route.loc[index, 'start_lat'] ,casual_geo_route.loc[index,'start_lng']] , [casual_geo_route.loc[index,'end_lat'], casual_geo_route.loc[index,'end_lng']]] 
    folium.PolyLine(locations = route , color='blue' , weight=0.5 , opacity = 0.4).add_to(m2)

# %%
m2.save('routesCasual-October.html')
