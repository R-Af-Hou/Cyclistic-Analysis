# %%
import pandas as pd

# %%
df1 = pd.read_csv("202411-Cyclistic.csv")

# %%
df1.head(20)
# Out:
#              ride_id  rideable_type      started_at        ended_at  \
# 0   84F37D091EAC31B6  electric_bike   11/24/24 7:09   11/24/24 7:10
# 1   E3660F57C587FB9D  electric_bike    11/8/24 3:37    11/8/24 3:37
# 2   FE9A79A14027EFEB  electric_bike  11/27/24 11:24  11/27/24 11:25
# 3   74D93ED5E2A9356F  electric_bike    11/6/24 8:40    11/6/24 8:41
# 4   18C2E31D89479586  electric_bike    11/4/24 0:27    11/4/24 0:28
# 5   CC0166FB7FF57E54  electric_bike   11/14/24 9:08   11/14/24 9:08
# 6   270161FE897943AB  electric_bike   11/5/24 19:01   11/5/24 19:02
# 7   6687C76A9FC29ACB  electric_bike   11/23/24 3:49   11/23/24 3:49
# 8   3639528807476671  electric_bike   11/3/24 11:21   11/3/24 11:21
# 9   A134F3A941B44A2D  electric_bike  11/19/24 17:43  11/19/24 17:43
# 10  74822B3CC66EF0B6  electric_bike  11/21/24 21:12  11/21/24 21:12
# 11  ECE484D267AE47E1  electric_bike   11/2/24 12:57   11/2/24 12:58
# 12  F187937438D796D3  electric_bike  11/16/24 19:07  11/16/24 19:07
# 13  905C52FFFDE7BF82  electric_bike   11/1/24 14:43   11/1/24 14:43
# 14  E6B28F2F062B76DA  electric_bike   11/23/24 8:42   11/23/24 8:42
# 15  B44743C4C5CC766F  electric_bike   11/3/24 17:42   11/3/24 17:42
# 16  4FBFC687F9E1FE44  electric_bike  11/26/24 15:23  11/26/24 15:23
# 17  4FB01DCB996C4068  electric_bike   11/3/24 11:18   11/3/24 11:18
# 18  57FB1FED70A29B1E  electric_bike  11/14/24 20:03  11/14/24 20:03
# 19  279B2156D64EC4F7  electric_bike  11/13/24 15:00  11/13/24 15:00
#
#     day_of_week  ride_length            start_station_name start_station_id  \
# 0           1.0         31.0          Broadway & Barry Ave            13137
# 1           6.0         31.0          Broadway & Barry Ave            13137
# 2           4.0         31.0                           NaN              NaN
# 3           4.0         31.0         Clark St & Berwyn Ave     KA1504000146
# 4           2.0         31.0                           NaN              NaN
# 5           5.0         31.0                           NaN              NaN
# 6           3.0         31.0         Calumet Ave & 33rd St            13217
# 7           7.0         31.0    N Carpenter St & W Lake St            20251
# 8           1.0         31.0         Michigan Ave & 8th St              623
# 9           3.0         31.0         Rush St & Superior St            15530
# 10          5.0         31.0          New St & Illinois St     TA1306000013
# 11          7.0         31.0   Lincoln Ave & Sunnyside Ave     TA1307000156
# 12          7.0         31.0        Damen Ave & Foster Ave     KA1504000149
# 13          6.0         31.0  Cornell Ave & Hyde Park Blvd     KA1503000007
# 14          7.0         31.0        Clark St & Drummond Pl     TA1307000142
# 15          1.0         31.0     Hampden Ct & Diversey Ave           202480
# 16          3.0         31.0        Benson Ave & Church St              596
# 17          1.0         31.0      LaSalle St & Illinois St            13430
# 18          5.0         31.0      LaSalle St & Illinois St            13430
# 19          4.0         31.0   Winchester Ave & Elston Ave     KA1504000140
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Broadway & Barry Ave          13137  41.937582 -87.644098
# 1           Broadway & Barry Ave          13137  41.937582 -87.644098
# 2                            NaN            NaN  41.860000 -87.650000
# 3          Clark St & Berwyn Ave   KA1504000146  41.978031 -87.668565
# 4                            NaN            NaN  41.940000 -87.680000
# 5                            NaN            NaN  41.890000 -87.630000
# 6          Calumet Ave & 33rd St          13217  41.834900 -87.617930
# 7     N Carpenter St & W Lake St          20251  41.885586 -87.653189
# 8          Michigan Ave & 8th St            623  41.872773 -87.623981
# 9          Rush St & Superior St          15530  41.895765 -87.625908
# 10          New St & Illinois St   TA1306000013  41.890847 -87.618617
# 11   Lincoln Ave & Sunnyside Ave   TA1307000156  41.963004 -87.684781
# 12        Damen Ave & Foster Ave   KA1504000149  41.975574 -87.679505
# 13  Cornell Ave & Hyde Park Blvd   KA1503000007  41.802406 -87.586924
# 14        Clark St & Drummond Pl   TA1307000142  41.931229 -87.644292
# 15     Hampden Ct & Diversey Ave         202480  41.932516 -87.642539
# 16        Benson Ave & Church St            596  42.048214 -87.683485
# 17      LaSalle St & Illinois St          13430  41.890762 -87.631697
# 18      LaSalle St & Illinois St          13430  41.890742 -87.631612
# 19   Winchester Ave & Elston Ave   KA1504000140  41.924091 -87.676460
#
#       end_lat    end_lng member_casual
# 0   41.937582 -87.644098        member
# 1   41.937582 -87.644098        member
# 2   41.860000 -87.650000        casual
# 3   41.978031 -87.668565        member
# 4   41.940000 -87.680000        casual
# 5   41.890000 -87.630000        casual
# 6   41.834900 -87.617930        member
# 7   41.885586 -87.653189        member
# 8   41.872773 -87.623981        casual
# 9   41.895765 -87.625908        member
# 10  41.890847 -87.618617        member
# 11  41.963004 -87.684781        casual
# 12  41.975811 -87.679510        member
# 13  41.802406 -87.586924        member
# 14  41.931248 -87.644336        member
# 15  41.932559 -87.642385        member
# 16  42.048214 -87.683485        casual
# 17  41.890762 -87.631697        member
# 18  41.890762 -87.631697        member
# 19  41.924091 -87.676460        member

# %%
import matplotlib.pyplot as plt

# %%
df1_weekday_count = df1[['day_of_week','member_casual']].value_counts()

# %%
df1_weekday_count.head(14)
# Out:
# day_of_week  member_casual
# 6.0          member           41991
# 3.0          member           37517
# 4.0          member           35470
# 2.0          member           35274
# 7.0          member           32931
# 5.0          member           28961
# 1.0          member           27940
# 7.0          casual           18995
# 1.0          casual           16630
# 6.0          casual           16348
# 2.0          casual           10529
# 3.0          casual           10301
# 4.0          casual            9815
# 5.0          casual            8723
# Name: count, dtype: int64

# %%
weekday_count_df = df1_weekday_count.reset_index()
weekday_count_df.columns = ['day_of_week', 'member_casual' , 'count']
weekday_count_df.head(15)
# Out:
#     day_of_week member_casual  count
# 0           6.0        member  41991
# 1           3.0        member  37517
# 2           4.0        member  35470
# 3           2.0        member  35274
# 4           7.0        member  32931
# 5           5.0        member  28961
# 6           1.0        member  27940
# 7           7.0        casual  18995
# 8           1.0        casual  16630
# 9           6.0        casual  16348
# 10          2.0        casual  10529
# 11          3.0        casual  10301
# 12          4.0        casual   9815
# 13          5.0        casual   8723

# %%
pivot_df1 = weekday_count_df.pivot_table(index='day_of_week' , columns='member_casual' , values='count')
pivot_df1
# Out:
# member_casual   casual   member
# day_of_week
# 1.0            16630.0  27940.0
# 2.0            10529.0  35274.0
# 3.0            10301.0  37517.0
# 4.0             9815.0  35470.0
# 5.0             8723.0  28961.0
# 6.0            16348.0  41991.0
# 7.0            18995.0  32931.0

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_df1['weekday'] = weekday

# %%
pivot_df1.plot(kind='bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
df1.hist(column='ride_length', bins=[30,120,300,600,1800,3600,10800,36000], by='member_casual')
plt.show()

# %%
df1_weekday_bike_membership = df1[['day_of_week','member_casual' , 'rideable_type']].value_counts()

# %%
weekday_bike_membership = df1_weekday_bike_membership.reset_index()

# %%
weekday_bike_membership.columns = ['day_of_week' , 'member_casual' , 'rideable_type' , 'count']

# %%
pivot_wbm = weekday_bike_membership.pivot_table(index = 'day_of_week' , columns = ['member_casual' , 'rideable_type'] , values = 'count')

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_wbm['weekday'] = weekday

# %%
pivot_wbm.plot(kind = 'bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
member_geo_data = df1[df1['member_casual']=='member']
member_geo_data = member_geo_data[['start_lat' , 'start_lng']]

# %%
member_geo_data.head()
# Out:
#    start_lat  start_lng
# 0  41.937582 -87.644098
# 1  41.937582 -87.644098
# 3  41.978031 -87.668565
# 6  41.834900 -87.617930
# 7  41.885586 -87.653189

# %%
HeatMap(member_geo_data).add_to(m)

# %%
m.save('heatmapmember-November.html')

# %%
casual_geo_data = df1[df1['member_casual']=='casual']
casual_geo_route = casual_geo_data[['start_lat' , 'start_lng' , 'end_lat' , 'end_lng']]
casual_geo_data = casual_geo_data[['start_lat' , 'start_lng']]

# %%
m1 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
HeatMap(casual_geo_data).add_to(m1)

# %%
m1.save('heatmapcasual-November.html')

# %%
m2 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
casual_geo_route.head()
# Out:
#     start_lat  start_lng    end_lat    end_lng
# 2   41.860000 -87.650000  41.860000 -87.650000
# 4   41.940000 -87.680000  41.940000 -87.680000
# 5   41.890000 -87.630000  41.890000 -87.630000
# 8   41.872773 -87.623981  41.872773 -87.623981
# 11  41.963004 -87.684781  41.963004 -87.684781

# %%
casual_geo_route = casual_geo_route.dropna()
for index in casual_geo_route.index:
    route = [[casual_geo_route.loc[index, 'start_lat'] ,casual_geo_route.loc[index,'start_lng']] , [casual_geo_route.loc[index,'end_lat'], casual_geo_route.loc[index,'end_lng']]] 
    folium.PolyLine(locations = route , color='blue' , weight=0.5 , opacity = 0.4).add_to(m2)

# %%
m2.save('routesCasual-November.html')
