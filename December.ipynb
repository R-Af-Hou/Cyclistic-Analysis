# %%
import pandas as pd

# %%
df1 = pd.read_csv("202412-Cyclistic.csv")

# %%
df1.head(20)
# Out:
#              ride_id  rideable_type      started_at        ended_at  \
# 0   9443ED3DD9C03BD1  electric_bike  12/21/24 11:25  12/21/24 11:26
# 1   B6259DF69E2314EA  electric_bike  12/26/24 13:25  12/26/24 13:25
# 2   D60617E92F22B7A2  electric_bike  12/16/24 15:54  12/16/24 15:54
# 3   4A51B1D030EE4745  electric_bike   12/29/24 0:34   12/29/24 0:34
# 4   28A3107AC689ECEB  electric_bike  12/10/24 12:16  12/10/24 12:17
# 5   FC5FCB7E77A06B0B  electric_bike   12/12/24 7:10   12/12/24 7:10
# 6   9CA0F6D7FD41493A  electric_bike   12/30/24 9:32   12/30/24 9:32
# 7   B67A22EF8576B7BD  electric_bike   12/13/24 7:41   12/13/24 7:41
# 8   8E95E432F623C047  electric_bike  12/21/24 15:27  12/21/24 15:27
# 9   EDD9180F1F986B97  electric_bike   12/6/24 16:17   12/6/24 16:17
# 10  410DBDF73AD18423  electric_bike   12/9/24 19:42   12/9/24 19:43
# 11  6EFFE4D1A25ECBEF  electric_bike  12/26/24 19:34  12/26/24 19:34
# 12  9ACB35A7D1C94E53  electric_bike  12/22/24 20:49  12/22/24 20:50
# 13  2E456BBDE90AC149  electric_bike  12/12/24 19:57  12/12/24 19:58
# 14  548569F4C5F24F9F  electric_bike  12/17/24 10:45  12/17/24 10:46
# 15  558146CC350D4B55  electric_bike   12/16/24 6:50   12/16/24 6:50
# 16  04AA8A932335CA8E  electric_bike   12/8/24 11:13   12/8/24 11:14
# 17  097D1216BDE72072  electric_bike  12/28/24 23:23  12/28/24 23:24
# 18  EBB5E734D2D5ACF8  electric_bike   12/1/24 14:44   12/1/24 14:44
# 19  96FBBAF66B9FBB51  electric_bike  12/28/24 16:36  12/28/24 16:36
#
#     day_of_week  ride_length               start_station_name  \
# 0             7           31                              NaN
# 1             5           31           State St & Randolph St
# 2             2           31          Franklin St & Monroe St
# 3             1           31          Stave St & Armitage Ave
# 4             3           31      Cottage Grove Ave & 67th St
# 5             5           31            Clark St & Newport St
# 6             2           31                              NaN
# 7             6           31     Racine Ave & Washington Blvd
# 8             7           31  Ravenswood Ave & Irving Park Rd
# 9             6           31            Kimbark Ave & 53rd St
# 10            2           31            Calumet Ave & 35th St
# 11            5           31           Wells St & Randolph St
# 12            1           31                              NaN
# 13            5           31            Canal St & Madison St
# 14            3           31           State St & Chicago Ave
# 15            2           31           St. Clair St & Erie St
# 16            1           31                              NaN
# 17            7           31                              NaN
# 18            1           31                              NaN
# 19            7           31                              NaN
#
#    start_station_id                 end_station_name end_station_id  \
# 0               NaN       Bissell St & Armitage Ave*   chargingstx1
# 1      TA1305000029           State St & Randolph St   TA1305000029
# 2      TA1309000007          Franklin St & Monroe St   TA1309000007
# 3             13266          Stave St & Armitage Ave          13266
# 4      KA1503000031      Cottage Grove Ave & 67th St   KA1503000031
# 5               632            Clark St & Newport St            632
# 6               NaN            Indiana Ave & 31st St   TA1308000036
# 7               654     Racine Ave & Washington Blvd            654
# 8      TA1307000149  Ravenswood Ave & Irving Park Rd   TA1307000149
# 9      TA1309000037            Kimbark Ave & 53rd St   TA1309000037
# 10            13345            Calumet Ave & 35th St          13345
# 11     TA1305000030           Wells St & Randolph St   TA1305000030
# 12              NaN                Wells St & Elm St   KA1504000135
# 13            13341                              NaN            NaN
# 14            21544                              NaN            NaN
# 15            13016                              NaN            NaN
# 16              NaN                              NaN            NaN
# 17              NaN                              NaN            NaN
# 18              NaN                              NaN            NaN
# 19              NaN                              NaN            NaN
#
#     start_lat  start_lng    end_lat    end_lng member_casual  Unnamed: 15
# 0   41.920000 -87.650000  41.918296 -87.652183        member          NaN
# 1   41.884621 -87.627834  41.884621 -87.627834        casual          NaN
# 2   41.880317 -87.635185  41.880317 -87.635185        member          NaN
# 3   41.917741 -87.691392  41.917741 -87.691392        casual          NaN
# 4   41.773721 -87.605635  41.773721 -87.605635        casual          NaN
# 5   41.944540 -87.654678  41.944540 -87.654678        member          NaN
# 6   41.840000 -87.620000  41.838842 -87.621857        member          NaN
# 7   41.883073 -87.656952  41.883073 -87.656952        casual          NaN
# 8   41.954622 -87.673908  41.954690 -87.673930        member          NaN
# 9   41.799455 -87.594778  41.799455 -87.594778        member          NaN
# 10  41.831379 -87.618034  41.831379 -87.618034        member          NaN
# 11  41.884295 -87.633963  41.884295 -87.633963        member          NaN
# 12  41.900000 -87.630000  41.903222 -87.634324        member          NaN
# 13  41.882409 -87.639767  41.880000 -87.640000        casual          NaN
# 14  41.896617 -87.628579  41.900000 -87.630000        member          NaN
# 15  41.894345 -87.622798  41.890000 -87.620000        member          NaN
# 16  41.800000 -87.590000  41.800000 -87.590000        casual          NaN
# 17  41.880000 -87.660000  41.880000 -87.660000        casual          NaN
# 18  41.790000 -87.590000  41.790000 -87.590000        member          NaN
# 19  41.970000 -87.650000  41.970000 -87.650000        member          NaN

# %%
import matplotlib.pyplot as plt

# %%
df1_weekday_count = df1[['day_of_week','member_casual']].value_counts()

# %%
df1_weekday_count.head(14)
# Out:
# day_of_week  member_casual
# 2            member           27511
# 3            member           25540
# 4            member           19824
# 5            member           17665
# 6            member           16781
# 1            member           16212
# 7            member           15101
# 2            casual            6965
# 7            casual            6161
# 1            casual            6033
# 3            casual            5613
# 5            casual            4319
# 4            casual            4290
# 6            casual            4264
# Name: count, dtype: int64

# %%
weekday_count_df = df1_weekday_count.reset_index()
weekday_count_df.columns = ['day_of_week', 'member_casual' , 'count']
weekday_count_df.head(15)
# Out:
#     day_of_week member_casual  count
# 0             2        member  27511
# 1             3        member  25540
# 2             4        member  19824
# 3             5        member  17665
# 4             6        member  16781
# 5             1        member  16212
# 6             7        member  15101
# 7             2        casual   6965
# 8             7        casual   6161
# 9             1        casual   6033
# 10            3        casual   5613
# 11            5        casual   4319
# 12            4        casual   4290
# 13            6        casual   4264

# %%
pivot_df1 = weekday_count_df.pivot_table(index='day_of_week' , columns='member_casual' , values='count')
pivot_df1
# Out:
# member_casual  casual   member
# day_of_week
# 1              6033.0  16212.0
# 2              6965.0  27511.0
# 3              5613.0  25540.0
# 4              4290.0  19824.0
# 5              4319.0  17665.0
# 6              4264.0  16781.0
# 7              6161.0  15101.0

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_df1['weekday'] = weekday

# %%
pivot_df1.plot(kind='bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
df1.hist(column='ride_length', bins=[30,120,300,600,1800,3600,10800,36000], by='member_casual')
plt.show()

# %%
df1_weekday_bike_membership = df1[['day_of_week','member_casual' , 'rideable_type']].value_counts()

# %%
weekday_bike_membership = df1_weekday_bike_membership.reset_index()

# %%
weekday_bike_membership.columns = ['day_of_week' , 'member_casual' , 'rideable_type' , 'count']

# %%
pivot_wbm = weekday_bike_membership.pivot_table(index = 'day_of_week' , columns = ['member_casual' , 'rideable_type'] , values = 'count')

# %%
weekday=['Sunday' , 'Monday' , 'Tuesday' , 'Wednesday' , 'Thursday' , 'Friday' , 'Saturday'] 
pivot_wbm['weekday'] = weekday

# %%
pivot_wbm.plot(kind = 'bar' , x='weekday')
# Out:
# <Axes: xlabel='weekday'>

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
member_geo_data = df1[df1['member_casual']=='member']
member_geo_data = member_geo_data[['start_lat' , 'start_lng']]

# %%
member_geo_data.head()
# Out:
#    start_lat  start_lng
# 0  41.920000 -87.650000
# 2  41.880317 -87.635185
# 5  41.944540 -87.654678
# 6  41.840000 -87.620000
# 8  41.954622 -87.673908

# %%
HeatMap(member_geo_data).add_to(m)

# %%
m.save('heatmapmember-December.html')

# %%
casual_geo_data = df1[df1['member_casual']=='casual']
casual_geo_route = casual_geo_data[['start_lat' , 'start_lng' , 'end_lat' , 'end_lng']]
casual_geo_data = casual_geo_data[['start_lat' , 'start_lng']]

# %%
m1 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
HeatMap(casual_geo_data).add_to(m1)

# %%
m1.save('heatmapcasual-December.html')

# %%
m2 = folium.Map(location=[42.50 , -82.50] , zoom_start = 5)

# %%
casual_geo_route.head()
# Out:
#     start_lat  start_lng    end_lat    end_lng
# 1   41.884621 -87.627834  41.884621 -87.627834
# 3   41.917741 -87.691392  41.917741 -87.691392
# 4   41.773721 -87.605635  41.773721 -87.605635
# 7   41.883073 -87.656952  41.883073 -87.656952
# 13  41.882409 -87.639767  41.880000 -87.640000

# %%
casual_geo_route = casual_geo_route.dropna()
for index in casual_geo_route.index:
    route = [[casual_geo_route.loc[index, 'start_lat'] ,casual_geo_route.loc[index,'start_lng']] , [casual_geo_route.loc[index,'end_lat'], casual_geo_route.loc[index,'end_lng']]] 
    folium.PolyLine(locations = route , color='blue' , weight=0.5 , opacity = 0.4).add_to(m2)

# %%
m2.save('routesCasual-December.html')

# %% [markdown]
# ##
